# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.9 MB/s eta 0:00:00
# ...

# %%
import pymongo
from pymongo import MongoClient

# %%
mongodb+srv://Sarah:<db_password>@cluster1.goyzc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1
