# %%
# def write_logins_to_file(username, password):
#     try:
#         file = open("./summative2.txt", "x")
#     except FileExistsError:
#         file = open("./summative2.txt", "a")
#         file.write(f"{username},{password}\n")
#         file.close()
#         return True
    
#     return False

# # Creating a function to ask user to create and confirm a username.
# def register():
#     print("You are in the registration process: ")
#     username = input("Enter your username: ")
#     print(f"This is your username {username}.")
#     confirm_username = input("Do you want to change your username?YES/NO: ")

#     # # Checking to see if user wants to change the username if YES, the while function allows the user to change it until user finally says NO and the script will return the username the above print function
#     while confirm_username == "YES":
#         username = input("What do you want to change your username to?")
#         confirm_username = input("Do you want to change your username?YES/NO: ")

#     # Writing a script for user to create a password in python programme    
#     password = input("Create your password: ")

#     # Creating a function to check the length of the password to meet the 12 characters criteria 
#     def check_password_length(password):
#         if len(password) < 12:
#             return False
#         else:
#             return True
  
#     # Using the while loop function, to tell user if the input password meets the criteria and if it does not to re-enter a password. This function will continue until the criteria is met.
#     while check_password_length(password) == False:
#         print("The password has to be at least 12 characters long.")
#         password = input("Enter a new password: ")
#         break
#     write_logins_to_file(username,password)
#     return username,password

# def read_logins_from_file():
#     credentials = {}
# # Checking to see if the text file exists  
#     try:
#         file = open("./summative2.txt", "x")
#     except FileExistsError:
#         file = open("./summative2.txt", "r")

#         line = file.readline()

#         while line != "" and line != None:
#             username,password = line.split(",")
#             password = password.split("\n")[0]
            
#             credentials[username] = password

#             line = file.readline()

#         file.close()
    
#     return credentials
# username,password = "",""
# def login(credentials):
#     global username, password
#     while True:
#         username = input("Enter username: ")
#         password = input("Enter your password: ")
# # Checks from the text file if the username & password keyed in is the same as what user previously registered.
#         try:
#             if credentials[username] == password:
#                 print(f"Welcome Back, {username}!")
#                 return True
#             else:
#                 print("Don't try to trick me!")
#             return False
#         except:
#             username, password = register()
#             return True


# credentials = read_logins_from_file()
# loggedIN = login(credentials)
# # print(username,password,loggedIn)

import random 

# Create a list for fruits category with 3 level of difficulties
def guessing_word_difficulty(level):
    fruits_list_lv1 = ['Apple', 'Banana', 'Orange', 'Mango', 'Pineapple',
                'Strawberry', 'Watermelon', 'Grapes', 'Pear','Peach', 
                'Plum', 'Kiwi', 'Avocado', 'Lemon','Lime',
                'Cherry', 'Blueberry', 'Raspberry','Blackberry', 'Papaya']
    fruits_list_lv2 = ['Apricot', 'Guava', 'Pomegranate', 'Fig', 'Passionfruit', 
                'Dragonfruit', 'Lychee', 'Persimmon','Cranberry','Starfruit',
                'Raspberry', 'Longan', 'Elderberry', 'Tangerine',
                'Clementine', 'Grapefruit', 'Pomelo', 'Cantaloupe', 'Honeydew', 
                'Nectarine'] 
    fruits_list_lv3 = ['Jackfruit', 'Persimmon', 'Mulberry', 'Pitaya',
                'Kiwifruit','Gooseberry', 'Kiwiberry', 'Plantain', 'Lemonade fruit',
                'Pawpaw', 'Soursop', 'Horned melon', 'Breadfruit', 'Jabuticaba',
                'Boysenberry', 'Soursop', 'Sapodilla', 'Salak', 'Ackee'] 
    if level == 'Easy':
        return random.choice(fruits_list_lv1)
    elif level == 'Medium':
        return random.choice(fruits_list_lv2)
    elif level == 'Hard':
        return random.choice(fruits_list_lv3)

# Crating the hangman images
hangman_images = [
    '''
    x---x
        |
        |
        |
       ===
    ''',
    '''
    x---x
    O   |
        |
        |
       ===
    ''',
    '''
    x---x
    O   |
    |   |
        |
       ===
    ''',
    '''
    x---x
    O   |
   /|   |
        |
       ===
    ''',
    '''
    x---x
    O   |
   /|\  |
        |
       ===
    ''',
    '''
    x---x
    O   |
   /|\  |
   /    |
       ===
    ''',
    '''
    x---x
    O   |
   /|\  |
   / \  |
       ===
    '''       ]

# User can choose difficulty level from low, medium or high
def game_difficulty():
      user_nickname = input("Enter a nickname: ")
      print("Selecting difficulty, in progres...")
      while True:
        print('A: Level->Easy')
        print('B: Level->Medium')
        print('C: Level->Hard')
        users_choice = input('Select Difficulty (A/B/C): ')

        level = ''
        if users_choice == 'A':
            level = 'fruits_list_level1'
        elif users_choice == 'B':
            level = 'fruits_list_level2'
        elif users_choice == 'C':
            level = 'fruits_list_level3'
        else: 
            print('Selection Invalid. Please select again.')
            return

guessing_word = guessing_word_difficulty(level)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a104e16479e2> in <cell line: 183>()
#     181             return
#     182
# --> 183 guessing_word = guessing_word_difficulty(level)
#
# NameError: name 'level' is not defined
